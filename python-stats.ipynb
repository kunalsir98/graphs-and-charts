# %%
data=[23,24,32,45,12,43,67,45,32,56,32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import pandas as pd

# %%
df2=pd.read_csv('https://raw.githubusercontent.com//sunnysavita10//Statistics-With-Python-CompleteGuide//main//Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-CompleteGuide/main/Titanic.csv')

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy=data.copy()

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
#mean
import numpy as np 
np.mean(data)
# Out:
# 37.36363636363637

# %%
#median 
np.median(data_copy)
# Out:
# 32.0

# %%
np.mean(df['SepalLengthCm'])
# Out:
# 5.843333333333334

# %%
#mode 
import statistics

# %%
statistics.mode(data)
# Out:
# 32

# %%
#manually calcultating mean
def mean(data):
    sum=0
    for i in data:
        sum=sum+i
    mean= sum/len(data)
    
    return(mean)

# %%
mean(data)
# Out:
# 37.36363636363637

# %%
from scipy import stats as st
st.mode(data)
# Out:
# ModeResult(mode=32, count=3)

# %%
data_copy.append(150)

# %%
np.mean(data_copy)
# Out:
# 46.75

# %%
data_copy2=data.copy()

# %%
data_copy2.append(75)

# %%
np.mean(data_copy2)
# Out:
# 40.5

# %%
np.median(data)
# Out:
# 32.0

# %%
np.median(data_copy)
# Out:
# 37.5

# %%
np.median(data_copy2)
# Out:
# 37.5

# %%
#dispersion

# %%
np.percentile(data,[25])
# Out:
# array([28.])

# %%
data_copy.pop()
# Out:
# 150

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
np.percentile(data,[25,50,75,100])
# Out:
# array([28., 32., 45., 67.])

# %%
data_copy.append(150)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150]

# %%
import seaborn as sns 
sns.boxplot(data_copy)
# Out:
# <Axes: >

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
np.random.choice(data,size=3)
# Out:
# array([67, 12, 32])

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.sample(n=15)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 137  138            6.4           3.1            5.5           1.8
# 117  118            7.7           3.8            6.7           2.2
# 43    44            5.0           3.5            1.6           0.6
# 108  109            6.7           2.5            5.8           1.8
# 21    22            5.1           3.7            1.5           0.4
# 75    76            6.6           3.0            4.4           1.4
# 74    75            6.4           2.9            4.3           1.3
# 83    84            6.0           2.7            5.1           1.6
# 116  117            6.5           3.0            5.5           1.8
# 15    16            5.7           4.4            1.5           0.4
# 29    30            4.7           3.2            1.6           0.2
# 112  113            6.8           3.0            5.5           2.1
# 16    17            5.4           3.9            1.3           0.4
# ...

# %%
np.var(data)
# Out:
# 226.23140495867773

# %%
np.std(data)
# Out:
# 15.040990823701666

# %%
import statistics 
statistics.variance(data)
# Out:
# 248.85454545454544

# %%
#corr/cov

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Species']=le.fit_transform(df['Species'])

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
# Species        0.942830       0.782561     -0.419446       0.949043
#
#                PetalWidthCm   Species
# Id                 0.899759  0.942830
# SepalLengthCm      0.817954  0.782561
# SepalWidthCm      -0.356544 -0.419446
# PetalLengthCm      0.962757  0.949043
# PetalWidthCm       1.000000  0.956464
# Species            0.956464  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    int32
# dtypes: float64(4), int32(1), int64(1)
# memory usage: 6.6 KB

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip  sex smoker   day    time  size
# 0         16.99  1.01    0     No   Sun  Dinner     2
# 1         10.34  1.66    1     No   Sun  Dinner     3
# 2         21.01  3.50    1     No   Sun  Dinner     3
# 3         23.68  3.31    1     No   Sun  Dinner     2
# 4         24.59  3.61    0     No   Sun  Dinner     4
# ..          ...   ...  ...    ...   ...     ...   ...
# 239       29.03  5.92    1     No   Sat  Dinner     3
# 240       27.18  2.00    0    Yes   Sat  Dinner     2
# 241       22.67  2.00    1    Yes   Sat  Dinner     2
# 242       17.82  1.75    1     No   Sat  Dinner     2
# 243       18.78  3.00    0     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
le=LabelEncoder()
df['sex']=le.fit_transform(df['sex'])
df['smoker']=le.fit_transform(df['smoker'])
df['day']=le.fit_transform(df['day'])
df['time']=le.fit_transform(df['time'])

# %%
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    2     0     2
# 1         10.34  1.66    1       0    2     0     3
# 2         21.01  3.50    1       0    2     0     3
# 3         23.68  3.31    1       0    2     0     2
# 4         24.59  3.61    0       0    2     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    3     0     2
#
# [244 rows x 7 columns]

# %%
df.corr()
# Out:
#             total_bill       tip       sex    smoker       day      time  \
# total_bill    1.000000  0.675734  0.144877  0.085721 -0.043550 -0.183118
# tip           0.675734  1.000000  0.088862  0.005929 -0.011548 -0.121629
# sex           0.144877  0.088862  1.000000  0.002816 -0.078292 -0.205231
# smoker        0.085721  0.005929  0.002816  1.000000 -0.282721 -0.054921
# day          -0.043550 -0.011548 -0.078292 -0.282721  1.000000  0.638019
# time         -0.183118 -0.121629 -0.205231 -0.054921  0.638019  1.000000
# size          0.598315  0.489299  0.086195 -0.133178  0.069510 -0.103411
#
#                 size
# total_bill  0.598315
# tip         0.489299
# sex         0.086195
# smoker     -0.133178
# day         0.069510
# time       -0.103411
# size        1.000000

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(x=df['tip'],y=df['size'])
# Out:
# <Axes: xlabel='tip', ylabel='size'>

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.scatterplot(x=df['tip'],y=df['total_bill'])
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
df.cov()
# Out:
#             total_bill       tip       sex    smoker       day      time  \
# total_bill   79.252939  8.323502  0.619041  0.371388 -0.359324 -0.732404
# tip           8.323502  1.914455  0.059013  0.003992 -0.014808 -0.075609
# sex           0.619041  0.059013  0.230368  0.000658 -0.034828 -0.044256
# smoker        0.371388  0.003992  0.000658  0.236845 -0.127521 -0.012008
# day          -0.359324 -0.014808 -0.034828 -0.127521  0.858986  0.265668
# time         -0.732404 -0.075609 -0.044256 -0.012008  0.265668  0.201848
# size          5.065983  0.643906  0.039348 -0.061644  0.061273 -0.044188
#
#                 size
# total_bill  5.065983
# tip         0.643906
# sex         0.039348
# smoker     -0.061644
# day         0.061273
# time       -0.044188
# size        0.904591

# %%
#pdf

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import seaborn as sns
sns.histplot(data,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    2     0     2
# 1         10.34  1.66    1       0    2     0     3
# 2         21.01  3.50    1       0    2     0     3
# 3         23.68  3.31    1       0    2     0     2
# 4         24.59  3.61    0       0    2     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    3     0     2
#
# [244 rows x 7 columns]

# %%
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.histplot(np.log(df2['SepalLengthCm']),kde=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(df2['SepalWidthCm'],kde=True)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(df2['PetalLengthCm'],kde=True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150]

# %%
data_copy.append(289)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150, 289]

# %%
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy4 = data.copy()

# %%
data_copy4
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32, 289]

# %%
data_copy4[0]=-10

# %%
data_copy4
# Out:
# [-10, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32, 289]

# %%
data_copy4[1]=-75

# %%
data_copy4
# Out:
# [-10, -75, 32, 45, 12, 43, 67, 45, 32, 56, 32, 289]

# %%
sns.histplot(data_copy4,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df2['PetalWidthCm'],kde=True)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
s=np.random.normal(0.5,0.2,1000)

# %%
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
p=np.random.lognormal(3.0,1.0,1000)

# %%
sns.histplot(p,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(p),kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32, 289]

# %%
data.pop()
# Out:
# 289

# %%
##qqplot
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(8,8))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(np.log(p))

# %%
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
le=LabelEncoder()

# %%
df2['Species']=le.fit_transform(df2['Species'])

# %%
#plot_data(df2)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame(np.random.randn(1000), index = pd.date_range('2024/06/22',periods=1000))

# %%
df
# Out:
#                    0
# 2024-06-22 -1.214668
# 2024-06-23 -1.179942
# 2024-06-24 -1.252294
# 2024-06-25 -2.009115
# 2024-06-26  0.029887
# ...              ...
# 2027-03-14  0.653860
# 2027-03-15  0.395298
# 2027-03-16  1.090585
# 2027-03-17  0.199270
# 2027-03-18  1.932901
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df= pd.read_csv("C:\\Users\\ACER\\Downloads\\Statistics-With-Python-TheCompleteGuide-main\\Statistics-With-Python-TheCompleteGuide-main\\Iris.csv")

# %%
df=df.drop(columns=['Id'],axis=1)

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df=df.head(20)

# %%
df.iloc[5:11].plot(kind='bar')
# Out:
# <Axes: >

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame(np.random.randn(1000), index = pd.date_range('2024/06/22',periods=1000))

# %%
df
# Out:
#                    0
# 2024-06-22  0.298637
# 2024-06-23 -0.709340
# 2024-06-24  1.633784
# 2024-06-25  1.105826
# 2024-06-26 -0.832206
# ...              ...
# 2027-03-14 -0.315399
# 2027-03-15  1.201106
# 2027-03-16  0.070441
# 2027-03-17 -0.583839
# 2027-03-18  0.615875
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df= pd.read_csv("C:\\Users\\ACER\\Downloads\\Statistics-With-Python-TheCompleteGuide-main\\Statistics-With-Python-TheCompleteGuide-main\\Iris.csv")

# %%
df=df.drop(columns=['Id'],axis=1)

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iloc[5:11].plot(kind='bar')
# Out:
# <Axes: >

# %%
df.iloc[[2]].plot(kind='bar')
# Out:
# <Axes: >

# %%
df.iloc[[2]].plot(kind='barh')
# Out:
# <Axes: >

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['SepalLengthCm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df['SepalLengthCm'].plot(kind='hist',orientation='horizontal')
# Out:
# <Axes: xlabel='Frequency'>

# %%
df.hist(figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='b')
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='r', alpha=0.1)
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
df.plot(kind='box',figsize=(20,10), color={'boxes':'g','whiskers':'b'})
# Out:
# <Axes: >

# %%
df.plot(kind='area',figsize=(20,10))
# Out:
# <Axes: >

# %%
df.plot(kind='area',figsize=(20,10), alpha=0.3, stacked=False)
# Out:
# <Axes: >

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x=['SepalLengthCm'],y=['PetalLengthCm'])
# Out:
# <Axes: xlabel='[SepalLengthCm]', ylabel='[PetalLengthCm]'>

# %%
df.plot.scatter(x='SepalLengthCm', y='PetalLengthCm',c='SepalWidthCm',s=600)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x='SepalLengthCm', y='PetalLengthCm',c='SepalWidthCm',s=df['PetalWidthCm']*600)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x='SepalLengthCm', y='PetalLengthCm',gridsize=20)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.iloc[[0]].head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa

# %%
df1=df.drop(columns='Species').iloc[0]

# %%
df1.plot(kind='pie')
# Out:
# <Axes: ylabel='0'>

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iplot()
# Out:
# <div>                            <div id="79106cc4-f054-4dc3-9178-7760e5e353e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='SepalLengthCm', y='PetalWidthCm', mode='markers')
# Out:
# <div>                            <div id="53ddd8e6-0a6c-4fc1-b4e3-a0a4708f33a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',mode='markers')
# Out:
# <div>                            <div id="537e0dcd-b864-4fdf-b9a9-16f3b4fb64d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble', x='SepalLengthCm', y='PetalLengthCm', size='PetalWidthCm' )
# Out:
# <div>                            <div id="f11c4002-1df8-40ed-8418-241edf4f4bd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="f7521250-83a6-42b2-9a00-34c0fe925afb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter3d',x='SepalLengthCm', y='PetalLengthCm', z='PetalWidthCm')
# Out:
# <div>                            <div id="95101ced-efcf-43f7-be34-bc0ee5f772bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble3d',x='SepalLengthCm', y='PetalLengthCm', z='PetalWidthCm',size='SepalWidthCm')
# Out:
# <div>                            <div id="483d2a31-54ec-4944-ac40-ff8e4bb2b678" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
